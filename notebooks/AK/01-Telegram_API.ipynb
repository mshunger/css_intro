# %% [markdown]
# # Basics of the Telegram API via telethon
# - Searching for channels
# - Collecting channel data
# - Collecting messages
# ---
# Prerequisites:
# - Basics of asyncio
# - Basics of time and date usage in python

# %% [markdown]
# # The Async Environment
# - the telethon package works on the asyncio framework
# - Pros:
#     - we can parallelize tasks to a certain extent
#     - we can use the telethon api ;)
# - Cons:
#     - we have to "await" results
#     - it is quite complicated
# - basic usage:
#     - we define functions, classes, for loops etc. with the `async` keword
#     - we sometimes need special asyncio versions of basic functions (e.g. `asyncio.sleep()` instead of `time.sleep()`)
# - mkr in depth information on asyncio can be found [here](https://realpython.com/async-io-python/)
#     - we `await` results of functions or generators

# %%
import asyncio

# %%
# example:
async def fun(x):
    print(x)
    await asyncio.sleep(1)
    print(x*2)

# %%
fun(1)
# Out:
# <coroutine object fun at 0x7fc0f967f8c0>

# %%
await fun(1)
# Out:
# 1
# 2

# %% [markdown]
# it can get much more omplicated than this!

# %% [markdown]
# ## Time and date in Python
# - many APIs and packages are used with datetime objects that take into account
#     - time
#     - date
#     - timezone
# - these formats can also be used to plot data by time (in R or Python)
# - two often used datetime objects are
#     - `datetime.datetime`
#         - understandable by humans
#         - we can get subinformation easily (day, hour, etc.)
#     - timestamps (seconds asince the start of the epoch on 01.01.1970 00:00:00 UTC)
#         - supplied by `time.time()`
#     - the formats are transferable into eachother

# %% [markdown]
# ### How do we get python to understand our time requirements?
# - We can supply time information as a string and let datetime parse it for us
#     - `dt.strptime(str, format)`
# - We can also transform datetime back to strings
#     - `dt.strftime(format)`
# - The formula has to be constructed using the a specific [format](https://docs.python.org/3/library/datetime.html#strftime-and-strptime-format-codes)

# %% [markdown]
# #### a few examples:

# %%
from datetime import datetime as dt
import time

# %%
today = time.time()

# %%
print(type(today), today)
# Out:
# <class 'float'> 1670233169.329538

# %%
today_dt = dt.fromtimestamp(today)
print(today_dt.day, today_dt.month, today_dt.year)
# Out:
# 5 12 2022

# %%
today_dt
# Out:
# datetime.datetime(2022, 12, 5, 10, 39, 29, 329538)

# %%
basic_format = '%Y-%m-%d %H:%M:%S'

# %%
today_str = today_dt.strftime(basic_format)
print(today_str)
# Out:
# 2022-12-05 10:39:29

# %% [markdown]
# #### and the other way round:

# %%
target_time = dt.strptime('2022-12-05 09:00:00', basic_format)
print(target_time)
# Out:
# 2022-12-05 09:00:00

# %% [markdown]
# ## using telethon with asyncio

# %% [markdown]
# ### connect to Telegram

# %%
from telethon import TelegramClient

# %%
key_path = '/Users/ungers/Documents/'

f = open(f"{key_path}tel.txt", "r")
lines = f.readlines()

access = dict()
for line in lines:
    info = line.split(' ')
    access[info[0]] = info[1][:-1]

# %%
api_id = access.get('id')
api_hash = access.get('hash')

# %%
client = TelegramClient('session', api_id, api_hash)

# %% [markdown]
# ### searching for channels

# %%
from telethon.tl.functions.contacts import SearchRequest

# %%
candidates = [
    'querdenken münster',
    'querdenken hannover',
    'querdenken hamm',
    '@V_Zelenskiy_official'
]

# %%
results = []
for candidate in candidates:
    async with client: # to use the logged in client
        result = await client(SearchRequest(candidate, limit=10))
        results.append(result)

# %%
for r in results:
    print(r.to_dict().get('results'))
# Out:
# [{'_': 'PeerChannel', 'channel_id': 1401905477}]
# [{'_': 'PeerChannel', 'channel_id': 1204340395}, {'_': 'PeerChannel', 'channel_id': 1444655522}, {'_': 'PeerChannel', 'channel_id': 1225384437}, {'_': 'PeerChannel', 'channel_id': 1216047451}]
# []
# [{'_': 'PeerChannel', 'channel_id': 1463721328}, {'_': 'PeerChannel', 'channel_id': 1666349486}, {'_': 'PeerUser', 'user_id': 5231283513}, {'_': 'PeerChannel', 'channel_id': 1705583914}, {'_': 'PeerChannel', 'channel_id': 1491537685}, {'_': 'PeerChannel', 'channel_id': 1782691297}, {'_': 'PeerChannel', 'channel_id': 1658667793}, {'_': 'PeerChannel', 'channel_id': 1811975001}, {'_': 'PeerChannel', 'channel_id': 1792252228}, {'_': 'PeerChannel', 'channel_id': 1823209522}]

# %% [markdown]
# ### Be careful with the results:
# - Are these actually the channels that you want?
# - you can check their verified status or other metadata

# %% [markdown]
# #### channel metadata

# %%
zel_search = results[3].to_dict().get('chats')

# %%
print(type(zel_search))
# Out:
# <class 'list'>

# %%
zel_search[0] # -> a dictionary!
# Out:
# {'_': 'Channel',
#  'id': 1463721328,
#  'title': 'Zelenskiy / Official',
#  'photo': {'_': 'ChatPhoto',
#   'photo_id': 5391153515738547595,
#   'dc_id': 2,
#   'has_video': False,
#   'stripped_thumb': b'\x01\x08\x08\xb0\xd7\t\xbc6\x08\x18\xc1\x1e\xf4QE+\x0e\xe7'},
#  'date': datetime.datetime(2019, 7, 30, 10, 57, 28, tzinfo=datetime.timezone.utc),
#  'creator': False,
#  'left': True,
#  'broadcast': True,
#  'verified': True,
#  'megagroup': False,
#  'restricted': False,
#  'signatures': False,
#  'min': False,
#  'scam': False,
#  'has_link': False,
#  'has_geo': False,
#  'slowmode_enabled': False,
#  'call_active': False,
#  'call_not_empty': False,
#  'fake': False,
#  'gigagroup': False,
#  'noforwards': False,
#  'join_to_send': False,
#  'join_request': False,
#  'access_hash': -6123649875255382059,
#  'username': 'V_Zelenskiy_official',
#  'restriction_reason': [],
#  'admin_rights': None,
#  'banned_rights': None,
#  'default_banned_rights': None,
#  'participants_count': 998837}

# %%
import pandas as pd

# %%
pd.DataFrame(zel_search)
# Out:
#          _          id                              title  \
# 0  Channel  1463721328               Zelenskiy / Official
# 1  Channel  1666349486               Zelenskiy / Official
# 2  Channel  1705583914  https://t.me/V_Zelenskiy_official
# 3  Channel  1491537685               Zelenskiy / Official
# 4  Channel  1782691297               Zelenskiy / Official
# 5  Channel  1658667793               Zelenskiy / Gospodar
# 6  Channel  1811975001                 Vладимир Zеленский
# 7  Channel  1792252228               Zelenskiy / Official
# 8  Channel  1823209522                 Владимир Зеленский
#
#                                                photo  \
# 0  {'_': 'ChatPhoto', 'photo_id': 539115351573854...
# 1  {'_': 'ChatPhoto', 'photo_id': 528102109245615...
# 2  {'_': 'ChatPhoto', 'photo_id': 526925862014141...
# 3  {'_': 'ChatPhoto', 'photo_id': 532125508336469...
# 4  {'_': 'ChatPhoto', 'photo_id': 545622876855846...
# 5  {'_': 'ChatPhoto', 'photo_id': 535703600923107...
# 6  {'_': 'ChatPhoto', 'photo_id': 519966653060492...
# 7  {'_': 'ChatPhoto', 'photo_id': 524696897682576...
# 8  {'_': 'ChatPhoto', 'photo_id': 532133277932308...
#
#                        date  creator  left  broadcast  verified  megagroup  \
# 0 2019-07-30 10:57:28+00:00    False  True       True      True      False
# 1 2022-03-09 15:37:34+00:00    False  True       True     False      False
# 2 2022-03-05 23:03:35+00:00    False  True       True     False      False
# 3 2020-11-23 03:40:46+00:00    False  True       True     False      False
# 4 2022-04-17 15:42:51+00:00    False  True       True     False      False
# 5 2022-04-04 14:37:31+00:00    False  True       True     False      False
# 6 2022-11-28 17:01:36+00:00    False  True       True     False      False
# 7 2022-02-26 05:55:49+00:00    False  True       True     False      False
# 8 2022-10-03 02:12:57+00:00    False  True       True     False      False
#
#    ...  noforwards  join_to_send  join_request          access_hash  \
# 0  ...       False         False         False -6123649875255382059
# 1  ...       False         False         False  5499308810924775981
# 2  ...       False         False         False  8134000323249237712
# 3  ...       False         False         False  4801566023759222217
# 4  ...       False         False         False   555692733303232414
# 5  ...       False         False         False  6807713629836820087
# 6  ...       False         False         False  6153153471697143018
# 7  ...       False         False         False  4279123952589928120
# 8  ...       False         False         False  4217281352986968766
#
#                 username  restriction_reason  admin_rights  banned_rights  \
# 0   V_Zelenskiy_official                  []          None           None
# 1    Zelenskyy_Volodymyr                  []          None           None
# 2             sluganarod                  []          None           None
# 3   V_Zelenskiy_officiaI                  []          None           None
# 4    V_Zelensky_official                  []          None           None
# 5  V_Zelenskiy_officiall                  []          None           None
# 6  VZ_Zelenskiy_Official                  []          None           None
# 7  V_Zelenskiyy_official                  []          None           None
# 8  V_Zelenskiy_official1                  []          None           None
#
#    default_banned_rights  participants_count
# 0                   None              998837
# 1                   None                 673
# 2                   None                  33
# 3                   None                   1
# 4                   None                  12
# 5                   None                   7
# 6                   None                   1
# 7                   None                   3
# 8                   None                   1
#
# [9 rows x 31 columns]

# %%
start_date = dt.strptime('2022-02-24 00:00:00', basic_format)

# %%
true_zel = results[3].chats[0]

# %%
async with client:
    messages = await client.get_messages(
        true_zel,
        reverse=True,
        offset_date=start_date,
        limit=500,
        #offset_id=offset
    )

# %%
type(messages)
# Out:
# telethon.helpers.TotalList

# %%
dicts = []
for message in messages:
    m = message.to_dict()
    dicts.append(m)

# %%
pd.DataFrame(dicts)
# Out:
#            _    id                                         peer_id  \
# 0    Message   725  {'_': 'PeerChannel', 'channel_id': 1463721328}
# 1    Message   726  {'_': 'PeerChannel', 'channel_id': 1463721328}
# 2    Message   727  {'_': 'PeerChannel', 'channel_id': 1463721328}
# 3    Message   728  {'_': 'PeerChannel', 'channel_id': 1463721328}
# 4    Message   729  {'_': 'PeerChannel', 'channel_id': 1463721328}
# ..       ...   ...                                             ...
# 495  Message  1229  {'_': 'PeerChannel', 'channel_id': 1463721328}
# 496  Message  1230  {'_': 'PeerChannel', 'channel_id': 1463721328}
# 497  Message  1231  {'_': 'PeerChannel', 'channel_id': 1463721328}
# 498  Message  1232  {'_': 'PeerChannel', 'channel_id': 1463721328}
# 499  Message  1233  {'_': 'PeerChannel', 'channel_id': 1463721328}
#
#                          date  \
# 0   2022-02-24 04:42:52+00:00
# 1   2022-02-24 06:48:58+00:00
# 2   2022-02-24 15:35:31+00:00
# 3   2022-02-24 21:26:30+00:00
# 4   2022-02-24 22:35:02+00:00
# ..                        ...
# 495 2022-04-12 18:08:16+00:00
# 496 2022-04-12 21:21:24+00:00
# 497 2022-04-12 23:40:37+00:00
# 498 2022-04-13 10:58:59+00:00
# 499 2022-04-13 12:09:40+00:00
#
#                                                message    out  mentioned  \
# 0                                    Ми – це Україна !  False      False
# 1    Я буду щогодини повідомляти вам актуальну і до...  False      False
# 2    Не Україна обрала шлях війни. Але Україна проп...  False      False
# 3    ​​Закликав лідерів ЄС – учасників надзвичайног...  False      False
# 4    Сьогодні Росія атакувала всю територію України...  False      False
# ..                                                 ...    ...        ...
# 495  Проведено спецоперацію завдяки СБУ. \nМолодці!...  False      False
# 496  Дуже символічно, що саме в День космонавтики б...  False      False
# 497  It is very symbolic that Mr. Medvedchuk was de...  False      False
# 498  Я закликаю Естонію при затвердженні нового сан...  False      False
# 499  I urge Estonia to defend the need for a comple...  False      False
#
#      media_unread  silent  post  ...  \
# 0           False   False  True  ...
# 1           False   False  True  ...
# 2           False   False  True  ...
# 3           False   False  True  ...
# 4           False   False  True  ...
# ..            ...     ...   ...  ...
# 495         False   False  True  ...
# 496         False   False  True  ...
# 497         False   False  True  ...
# 498         False   False  True  ...
# 499         False   False  True  ...
#
#                                               entities    views  forwards  \
# 0                                                   []  3311528     41069
# 1                                                   []  3198333     19559
# 2                                                   []  2595219      9948
# 3    [{'_': 'MessageEntityTextUrl', 'offset': 0, 'l...  2073752      3284
# 4                                                   []  3430887     12440
# ..                                                 ...      ...       ...
# 495                                                 []  6236642     92245
# 496                                                 []  4958974     10501
# 497                                                 []   624482       352
# 498                                                 []  3448526      1135
# 499                                                 []   490420       112
#
#      replies  edit_date post_author grouped_id reactions restriction_reason  \
# 0       None        NaT        None        NaN      None                 []
# 1       None        NaT        None        NaN      None                 []
# 2       None        NaT        None        NaN      None                 []
# 3       None        NaT        None        NaN      None                 []
# 4       None        NaT        None        NaN      None                 []
# ..       ...        ...         ...        ...       ...                ...
# 495     None        NaT        None        NaN      None                 []
# 496     None        NaT        None        NaN      None                 []
# 497     None        NaT        None        NaN      None                 []
# 498     None        NaT        None        NaN      None                 []
# 499     None        NaT        None        NaN      None                 []
#
#     ttl_period
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
# ..         ...
# 495       None
# 496       None
# 497       None
# 498       None
# 499       None
#
# [500 rows x 31 columns]

# %%
from tqdm.notebook import tqdm

# %%
loop = True
first = True
offset = True

all_messages = []

while loop:
    if first:
        async with client:
            messages = await client.get_messages(
                true_zel,
                reverse=True,
                offset_date=start_date,
                limit=500,
            )

        for m in tqdm(messages):
            all_messages.append(m.to_dict())
            
        offset = messages[-1].to_dict().get('id')
        
        if len(messages) < 500:
            loop=False
        
        first = False
        
    else:
        async with client:
            messages = await client.get_messages(
                true_zel,
                reverse=True,
                offset_date=start_date,
                limit=500,
                offset_id=offset
            )

        for m in tqdm(messages):
            all_messages.append(m.to_dict())
        
        offset = messages[-1].to_dict().get('id')
        
        if len(messages) < 500:
            loop=False
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/38 [00:00<?, ?it/s]

# %%
pd.DataFrame(all_messages)
# Out:
#             _    id                                         peer_id  \
# 0     Message   725  {'_': 'PeerChannel', 'channel_id': 1463721328}
# 1     Message   726  {'_': 'PeerChannel', 'channel_id': 1463721328}
# 2     Message   727  {'_': 'PeerChannel', 'channel_id': 1463721328}
# 3     Message   728  {'_': 'PeerChannel', 'channel_id': 1463721328}
# 4     Message   729  {'_': 'PeerChannel', 'channel_id': 1463721328}
# ...       ...   ...                                             ...
# 3533  Message  4282  {'_': 'PeerChannel', 'channel_id': 1463721328}
# 3534  Message  4283  {'_': 'PeerChannel', 'channel_id': 1463721328}
# 3535  Message  4284  {'_': 'PeerChannel', 'channel_id': 1463721328}
# 3536  Message  4285  {'_': 'PeerChannel', 'channel_id': 1463721328}
# 3537  Message  4287  {'_': 'PeerChannel', 'channel_id': 1463721328}
#
#                           date  \
# 0    2022-02-24 04:42:52+00:00
# 1    2022-02-24 06:48:58+00:00
# 2    2022-02-24 15:35:31+00:00
# 3    2022-02-24 21:26:30+00:00
# 4    2022-02-24 22:35:02+00:00
# ...                        ...
# 3533 2022-12-04 09:38:19+00:00
# 3534 2022-12-04 09:38:19+00:00
# 3535 2022-12-04 09:38:19+00:00
# 3536 2022-12-04 19:28:25+00:00
# 3537 2022-12-04 20:59:49+00:00
#
#                                                 message    out  mentioned  \
# 0                                     Ми – це Україна !  False      False
# 1     Я буду щогодини повідомляти вам актуальну і до...  False      False
# 2     Не Україна обрала шлях війни. Але Україна проп...  False      False
# 3     ​​Закликав лідерів ЄС – учасників надзвичайног...  False      False
# 4     Сьогодні Росія атакувала всю територію України...  False      False
# ...                                                 ...    ...        ...
# 3533                                                     False      False
# 3534                                                     False      False
# 3535                                                     False      False
# 3536  Минає четвертий день цієї зими. Зими, яка буде...  False      False
# 3537  The fourth day of this winter is coming to an ...  False      False
#
#       media_unread  silent  post  ...      views  forwards replies  \
# 0            False   False  True  ...  3311528.0   41069.0     NaN
# 1            False   False  True  ...  3198333.0   19559.0     NaN
# 2            False   False  True  ...  2595219.0    9948.0     NaN
# 3            False   False  True  ...  2073752.0    3284.0     NaN
# 4            False   False  True  ...  3430887.0   12440.0     NaN
# ...            ...     ...   ...  ...        ...       ...     ...
# 3533         False   False  True  ...   614715.0     282.0     NaN
# 3534         False   False  True  ...   615093.0     297.0     NaN
# 3535         False   False  True  ...   617179.0     278.0     NaN
# 3536         False   False  True  ...  2222678.0    1164.0     NaN
# 3537         False   False  True  ...   121824.0      46.0     NaN
#
#                      edit_date post_author    grouped_id  reactions  \
# 0                          NaT         NaN           NaN        NaN
# 1                          NaT         NaN           NaN        NaN
# 2                          NaT         NaN           NaN        NaN
# 3                          NaT         NaN           NaN        NaN
# 4                          NaT         NaN           NaN        NaN
# ...                        ...         ...           ...        ...
# 3533                       NaT         NaN  1.336117e+16        NaN
# 3534                       NaT         NaN  1.336117e+16        NaN
# 3535                       NaT         NaN  1.336117e+16        NaN
# 3536 2022-12-04 19:28:35+00:00         NaN           NaN        NaN
# 3537                       NaT         NaN           NaN        NaN
#
#       restriction_reason ttl_period action
# 0                     []       None    NaN
# 1                     []       None    NaN
# 2                     []       None    NaN
# 3                     []       None    NaN
# 4                     []       None    NaN
# ...                  ...        ...    ...
# 3533                  []       None    NaN
# 3534                  []       None    NaN
# 3535                  []       None    NaN
# 3536                  []       None    NaN
# 3537                  []       None    NaN
#
# [3538 rows x 32 columns]
